# %% [markdown]
# # Titanic Data Loading
#
# This notebook was used to understand the dataset before starting preprocessing and modeling.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/Titanic-Dataset.csv')
df.head()

# %%
df.shape

# %%
df.columns.tolist()

# %%
df.info()

# %%
df.describe(include='all')
