# %% [markdown]
# # Final Notes
#
# This notebook was used to summarize what I wanted to keep in the final project.

# %% [markdown]
# ## Main points
#
# - Keep the app simple
# - Show EDA clearly
# - Compare a few models
# - Add prediction form in Streamlit
# - Save charts in the reports folder

# %% [markdown]
# ## Final project flow
#
# 1. Check dataset in notebook
# 2. Clean missing values
# 3. Make EDA charts
# 4. Train models
# 5. Build Streamlit app
